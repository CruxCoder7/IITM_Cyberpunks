# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopy
db = pd.read_csv("./datasets/mockData.csv")
db.dtypes
db["Time"] = pd.to_datetime(db["Time"])
db["Hour"] = db.Time.apply(lambda x: x.hour)
db.Hour.rolling(5).mean().plot()

y = db.Hour.rolling(5).mean()

a = plt.hlines(db.Hour.describe()["25%"],0,100,'r')
b = plt.hlines(db.Hour.describe()["75%"],0,100,'r')
y+5
db.Hour.describe()["25%"]
# Out:
# 12.0
